# %% [markdown]
# # Enterprise Operations AI Assistant
#
# A simple multi-agent business automation platform for NovaTech Solutions Pvt. Ltd.

# %% [markdown]
# ## 1. Project Overview
#
# This project develops an Enterprise Operations AI Assistant for NovaTech Solutions Pvt. Ltd. The system will eventually automate common business operations using multiple specialized AI agents.

# %% [markdown]
# ## 2. Problem Statement
#
# Business employees often need to search company policies, perform research, process information, and communicate through email. These activities can be time-consuming when handled manually.

# %% [markdown]
# ## 3. Project Objective
#
# The objective is to build a simple AI-assisted platform that can eventually coordinate multiple business automation tasks through specialized agents.

# %% [markdown]
# ## 4. System Architecture
#
# This section will document the architecture of the Enterprise Operations AI Assistant, including the coordinator, specialized agents, knowledge base, tools, workflows, and application interface.

# %% [markdown]
# ## 5. Technology Stack
#
# The project will use Python, uv, Jupyter, LangChain, OpenRouter, ChromaDB, Streamlit, and other supporting technologies introduced during later development steps.

# %% [markdown]
# ## 6. Project Setup
#
# This section documents the GitHub repository, uv project configuration, dependencies, project structure, and development environment.

# %% [markdown]
# ## 7. Environment Configuration
#
# This section will document environment variables and configuration required by the project. API keys will be stored locally and excluded from Git.

# %% [markdown]
# ## 8. LLM Setup
#
# This section will later document the OpenRouter and LangChain LLM configuration.

# %% [markdown]
# ## 8. LLM Setup
#
# This section will later document the OpenRouter and LangChain LLM configuration.

# %% [markdown]
# ## 9. Company Knowledge Base
#
# This section will later document the sample company documents and the retrieval-based knowledge system.

# %% [markdown]
# ## 10. Multi-Agent System
#
# This section will later document the specialized agents responsible for different business operations.

# %% [markdown]
# ## 11. Agent Routing
#
# This section will later document how incoming requests are routed to the appropriate agent.

# %% [markdown]
# ## 12. Sequential Workflow
#
# This section will later document the sequential execution of multiple business operations.

# %% [markdown]
# ## 13. Parallel Processing
#
# This section will later document how independent operations can be executed in parallel.

# %% [markdown]
# ## 14. Memory
#
# This section will later document short-term and long-term memory for the assistant.

# %% [markdown]
# ## 15. Structured Outputs
#
# This section will later document structured responses and validation using Pydantic.

# %% [markdown]
# ## 16. Python Tools
#
# This section will later document Python-based tools that can be used by the agents.

# %% [markdown]
# ## 17. Streamlit Application
#
# This section will later document the Streamlit interface used to interact with the Enterprise Operations AI Assistant.

# %% [markdown]
# ## 18. Testing
#
# This section will later document testing, validation, and debugging performed throughout the project.

# %% [markdown]
# ## 19. Results
#
# This section will later document the final results and demonstrated capabilities of the system.

# %% [markdown]
# ## 20. Conclusion
#
# This section will later summarize the completed Enterprise Operations AI Assistant and the key concepts demonstrated by the project.

# %%
# system checks
import sys

print("Python:", sys.version)
print("Executable:", sys.executable)
# Out:
# Python: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Executable: c:\Users\Edlyn Jessica\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Scripts\python.exe

# %%
import streamlit
import dotenv
import langchain_core
import langchain_openai

print("Initial dependencies working.")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import streamlit
#       2 import dotenv
#       3 import langchain_core
# ----> 4 import langchain_openai
#       5
#       6 print("Initial dependencies working.")
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_openai\__init__.py:4
#       1 """Module for OpenAI integrations."""
#       3 from langchain_openai._version import __version__
# ----> 4 from langchain_openai.chat_models import AzureChatOpenAI, ChatOpenAI
#       5 from langchain_openai.chat_models._client_utils import StreamChunkTimeoutError
#       6 from langchain_openai.embeddings import AzureOpenAIEmbeddings, OpenAIEmbeddings
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_openai\chat_models\__init__.py:3
#       1 """Module for OpenAI chat models."""
# ----> 3 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       4 from langchain_openai.chat_models.base import ChatOpenAI
#       6 __all__ = ["AzureChatOpenAI", "ChatOpenAI"]
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_openai\chat_models\azure.py:11
#       8 from typing import TYPE_CHECKING, Any, Literal, TypeAlias, TypeVar
#      10 import openai
# ---> 11 from langchain_core.language_models import LanguageModelInput
#      12 from langchain_core.language_models.chat_models import LangSmithParams
#      13 from langchain_core.outputs import ChatGenerationChunk, ChatResult
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_core\language_models\base.py:37
#      25 from langchain_core.messages import (
#      26     AIMessage,
#      27     AnyMessage,
#    (...)     30     get_buffer_string,
#      31 )
#      32 from langchain_core.prompt_values import (
#      33     ChatPromptValueConcrete,
#      34     PromptValue,
#      35     StringPromptValue,
#      36 )
# ---> 37 from langchain_core.runnables import Runnable, RunnableSerializable
#      39 if TYPE_CHECKING:
#      40     from langchain_core.outputs import LLMResult
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_core\runnables\__init__.py:130, in __getattr__(attr_name)
#     128 def __getattr__(attr_name: str) -> object:
#     129     module_name = _dynamic_imports.get(attr_name)
# --> 130     result = import_attr(attr_name, module_name, __spec__.parent)
#     131     globals()[attr_name] = result
#     132     return result
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_core\_import_utils.py:39, in import_attr(attr_name, module_name, package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
# ---> 39         raise ImportError(msg) from None
#      40     result = getattr(module, attr_name)
#      41 return result
#
# ImportError: module ''langchain_core.runnables'.'base'' not found (No module named 'jsonpatch')
