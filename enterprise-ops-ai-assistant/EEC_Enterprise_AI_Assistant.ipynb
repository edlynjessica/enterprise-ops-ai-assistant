# %% [markdown]
# # Enterprise Operations AI Assistant
#
# A simple multi-agent business automation platform for NovaTech Solutions Pvt. Ltd.

# %% [markdown]
# ## 1. Project Overview
#
# This project develops an Enterprise Operations AI Assistant for NovaTech Solutions Pvt. Ltd. The system will eventually automate common business operations using multiple specialized AI agents.

# %% [markdown]
# ## 2. Problem Statement
#
# Business employees often need to search company policies, perform research, process information, and communicate through email. These activities can be time-consuming when handled manually.

# %% [markdown]
# ## 3. Project Objective
#
# The objective is to build a simple AI-assisted platform that can eventually coordinate multiple business automation tasks through specialized agents.

# %% [markdown]
# ## 4. System Architecture
#
# This section will document the architecture of the Enterprise Operations AI Assistant, including the coordinator, specialized agents, knowledge base, tools, workflows, and application interface.

# %% [markdown]
# ## 5. Technology Stack
#
# The project will use Python, uv, Jupyter, LangChain, OpenRouter, ChromaDB, Streamlit, and other supporting technologies introduced during later development steps.

# %% [markdown]
# ## 6. Project Setup
#
# This section documents the GitHub repository, uv project configuration, dependencies, project structure, and development environment.

# %% [markdown]
# ## 7. Environment Configuration
#
# This section will document environment variables and configuration required by the project. API keys will be stored locally and excluded from Git.

# %% [markdown]
# ### Environment Variables
#
# The OpenRouter API key is stored in a local `.env` file rather than directly in the source code.
#
# This prevents sensitive credentials from being hardcoded or accidentally committed to GitHub.
#
# The `.env` file is excluded from Git using `.gitignore`.

# %% [markdown]
# ## 8. LLM Setup
#
# This section will later document the OpenRouter and LangChain LLM configuration.

# %% [markdown]
# ### OpenRouter
#
# OpenRouter provides an OpenAI-compatible API that allows the application to access the selected language model using the `ChatOpenAI` integration from LangChain.
#
# The model used in this project is:
#
# `openai/gpt-oss-20b`
#
# ### LangChain
#
# LangChain provides components for interacting with chat models and constructing reusable processing chains.
#
# ### ChatPromptTemplate
#
# `ChatPromptTemplate` allows us to define a reusable prompt containing variables that can be filled with user input.
#
# ### LCEL
#
# LangChain Expression Language (LCEL) allows components to be connected using a simple pipeline.
#
# The basic flow used in this step is:
#
# Prompt → LLM → Response

# %% [markdown]
# ## 9. Company Knowledge Base
#
# Creating Company Policy Documents
# PDF Loader
# Text Splitting
# Embeddings
# ChromaDB
# Retriever
# Retrieval-Augmented Generation (RAG)
# RAG Testing

# %% [markdown]
# ### Creating Company Policy Documents
#
# For this academic project, four fictional company policy documents are created:
#
# - Leave Policy
# - Attendance Policy
# - Work From Home Policy
# - Employee Handbook

# %% [markdown]
# ## 10. Multi-Agent System
#
# The Enterprise Operations AI Assistant will eventually contain multiple specialized agents.
#
# Each agent will be responsible for a specific business function.
#
# In this step, the HR Agent is implemented.
#
# ### 10.1 HR Agent
#
# The HR Agent is responsible for answering employee questions related to leave, attendance, work from home, and general employee policies.
#
# It uses the existing company knowledge base and RAG system to provide answers grounded in NovaTech Solutions Pvt. Ltd. documents.
#
# ### HR Agent Responsibilities
#
# The HR Agent handles:
#
# - Leave policy questions
# - Attendance policy questions
# - Work From Home questions
# - Employee handbook questions
# - General employee policy questions
#
# The agent uses the company knowledge base as its primary source and should not invent policies that are not present in the retrieved documents.
#
# ### HR Agent Architecture
#
# The HR Agent uses the existing ChromaDB retriever and OpenRouter LLM.
#
# Employee HR Question
# ↓
# HR Agent
# ↓
# HR-specific instructions
# ↓
# Retriever
# ↓
# Relevant Company Documents
# ↓
# OpenRouter LLM
# ↓
# HR Answer

# %% [markdown]
# ## 11. Agent Routing
#
# This section will later document how incoming requests are routed to the appropriate agent.

# %% [markdown]
# ## 12. Sequential Workflow
#
# This section will later document the sequential execution of multiple business operations.

# %% [markdown]
# ## 13. Parallel Processing
#
# This section will later document how independent operations can be executed in parallel.

# %% [markdown]
# ## 14. Memory
#
# This section will later document short-term and long-term memory for the assistant.

# %% [markdown]
# ## 15. Structured Outputs
#
# This section will later document structured responses and validation using Pydantic.

# %% [markdown]
# ## 16. Python Tools
#
# This section will later document Python-based tools that can be used by the agents.

# %% [markdown]
# ## 17. Streamlit Application
#
# This section will later document the Streamlit interface used to interact with the Enterprise Operations AI Assistant.

# %% [markdown]
# ## 18. Testing
#
# This section will later document testing, validation, and debugging performed throughout the project.

# %% [markdown]
# ## 19. Results
#
# This section will later document the final results and demonstrated capabilities of the system.

# %% [markdown]
# ## 20. Conclusion
#
# This section will later summarize the completed Enterprise Operations AI Assistant and the key concepts demonstrated by the project.

# %%
# system checks
import sys

print("Python:", sys.version)
print("Executable:", sys.executable)
# Out:
# Python: 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]
# Executable: c:\Users\Edlyn Jessica\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Scripts\python.exe

# %%
import os
from dotenv import load_dotenv

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from langchain_core.prompts import ChatPromptTemplate

# %%
load_dotenv()

api_key = os.getenv("OPENROUTER_API_KEY")

if api_key:
    print("OpenRouter API Key Found")
else:
    print("OpenRouter API Key Not Found")
# Out:
# OpenRouter API Key Found

# %%
llm = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key,
    model="openai/gpt-oss-20b",
    temperature=0
)

# %%
response = llm.invoke([
    HumanMessage(
        content="What is an Enterprise AI Assistant? Explain in two sentences."
    )
])

print(response.content)
# Out:
# An Enterprise AI Assistant is a cloud‑based, AI‑powered chatbot or virtual agent that integrates with a company’s internal systems—such as CRM, ERP, and knowledge bases—to automate routine tasks, answer employee and customer queries, and provide data‑driven insights. It is designed for scalability, security, and compliance, enabling organizations to streamline operations, improve productivity, and deliver consistent, context‑aware support across the enterprise.

# %% [markdown]
# ### ChatPromptTemplate
#
# A chat prompt template creates a reusable prompt structure with placeholders for dynamic information.
#
# Here, the employee's question is represented using `{question}`.

# %%
prompt = ChatPromptTemplate.from_template(
    """You are an AI assistant for NovaTech Solutions Pvt. Ltd.

Answer the employee's question clearly and professionally.

Employee question:
{question}
"""
)

# %%
prompt_message = prompt.invoke({
    "question": "What are the responsibilities of the HR department?"
})

response = llm.invoke(prompt_message)

print(response.content)
# Out:
# **Responsibilities of the HR Department**
#
# | Area | Key Responsibilities | Purpose |
# |------|----------------------|---------|
# | **Recruitment & Staffing** | • Define workforce needs<br>• Source, screen, interview, and hire candidates<br>• Manage job postings, applicant tracking, and onboarding | Build a skilled, diverse, and engaged workforce |
# | **Employee Onboarding & Orientation** | • Coordinate orientation programs<br>• Ensure new hires receive necessary training, equipment, and access | Accelerate productivity and integration |
# | **Performance Management** | • Design and implement performance appraisal systems<br>• Provide coaching and feedback<br>• Identify high‑potential talent | Align individual goals with company objectives |
# | **Training & Development** | • Assess training needs<br>• Deliver or coordinate learning programs<br>• Track skill development | Foster continuous growth and skill enhancement |
# | **Compensation & Benefits** | • Develop salary structures and bonus plans<br>• Administer health, retirement, and other benefits<br>• Conduct market benchmarking | Attract, retain, and reward talent |
# | **Employee Relations & Engagement** | • Address grievances and conflicts<br>• Conduct employee surveys and engagement initiatives<br>• Promote a positive workplace culture | Maintain high morale and reduce turnover |
# | **HR Policies & Compliance** | • Draft, update, and enforce HR policies<br>• Ensure compliance with labor laws, safety regulations, and data protection standards | Mitigate legal risk and uphold ethical standards |
# | **Workforce Planning & Analytics** | • Forecast staffing needs<br>• Analyze workforce metrics (turnover, diversity, productivity)<br>• Provide data-driven insights to leadership | Support strategic decision‑making |
# | **HR Information Systems (HRIS)** | • Maintain employee data integrity<br>• Generate reports and dashboards<br>• Ensure data security | Enable efficient HR operations |
# | **Health & Safety** | • Implement workplace safety programs<br>• Conduct risk assessments and incident investigations | Protect employee well‑being and comply with regulations |
# | **Succession Planning** | • Identify critical roles and potential successors<br>• Develop leadership pipelines | Ensure business continuity |
#
# **Strategic Role**
#
# Beyond day‑to‑day operations, the HR department acts as a strategic partner, aligning human capital initiatives with the company’s long‑term goals, fostering innovation, and driving organizational culture.
#
# Feel free to let me know if you need more detail on any specific area!

# %% [markdown]
# ### Simple LCEL Chain
#
# LangChain Expression Language allows the prompt and language model to be connected using the pipe operator.
#
# The flow is:
#
# Prompt → LLM → Response

# %%
chain = prompt | llm

# %%
response = chain.invoke({
    "question": "What are the responsibilities of the HR department?"
})

print(response.content)
# Out:
# **Responsibilities of the HR Department**
#
# The Human Resources (HR) department serves as the backbone of NovaTech Solutions Pvt. Ltd., ensuring that our people—our most valuable asset—are recruited, developed, supported, and retained in a way that aligns with our business objectives. Below is a concise overview of the core responsibilities:
#
# | # | Core Responsibility | Key Activities |
# |---|---------------------|----------------|
# | **1** | **Talent Acquisition & Onboarding** | • Design and execute recruitment strategies (job postings, sourcing, interviewing). <br>• Conduct background checks, reference verification, and offer negotiations. <br>• Manage new‑hire orientation, documentation, and integration into teams. |
# | **2** | **Learning & Development** | • Identify skill gaps and create training programs (on‑the‑job, e‑learning, workshops). <br>• Track employee progress and ROI of development initiatives. |
# | **3** | **Performance Management** | • Implement performance appraisal systems (goal setting, mid‑year reviews, annual reviews). <br>• Provide coaching and feedback mechanisms. |
# | **4** | **Compensation & Benefits** | • Design competitive salary structures and bonus plans. <br>• Administer health, retirement, and other benefit programs. |
# | **5** | **Employee Relations & Engagement** | • Serve as a trusted advisor for employee concerns and conflict resolution. <br>• Conduct engagement surveys, analyze results, and recommend action plans. |
# | **6** | **Policy & Compliance** | • Draft, update, and enforce HR policies in line with local labor laws and industry standards. <br>• Ensure compliance with data protection (GDPR, local privacy laws) and workplace safety regulations. |
# | **7** | **Workforce Planning & Analytics** | • Forecast staffing needs, succession planning, and talent pipelines. <br>• Use HRIS data to generate reports on turnover, headcount, diversity, and other key metrics. |
# | **8** | **Exit & Off‑boarding** | • Conduct exit interviews, manage final settlements, and ensure knowledge transfer. |
# | **9** | **Strategic Partnering** | • Collaborate with senior leadership to align HR initiatives with business strategy (growth, innovation, culture). <br>• Provide insights on organizational design and change management. |
#
# ### How HR Supports NovaTech’s Mission
#
# - **People‑First Culture:** By fostering a supportive environment, HR helps us attract and retain top talent, driving innovation and customer satisfaction.
# - **Operational Excellence:** Efficient processes (recruitment, onboarding, performance) reduce time‑to‑hire, improve productivity, and lower costs.
# - **Risk Mitigation:** Proactive compliance and policy management protect the company from legal and reputational risks.
# - **Strategic Growth:** Workforce analytics and talent planning enable us to scale operations in line with market demands.
#
# If you have any specific questions about a particular HR function or need assistance with a process, feel free to reach out to the HR team at hr@novatech.com.

# %%
from pathlib import Path
from reportlab.lib.pagesizes import A4
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet

documents_dir = Path("documents")
documents_dir.mkdir(exist_ok=True)

styles = getSampleStyleSheet()


def create_pdf(filename, title, content):
    file_path = documents_dir / filename

    doc = SimpleDocTemplate(
        str(file_path),
        pagesize=A4
    )

    story = [
        Paragraph(title, styles["Title"]),
        Spacer(1, 20)
    ]

    for paragraph in content:
        story.append(
            Paragraph(paragraph, styles["BodyText"])
        )
        story.append(Spacer(1, 10))

    doc.build(story)

    print(f"Created: {file_path}")

# %%
create_pdf(
    "leave_policy.pdf",
    "NovaTech Solutions Pvt. Ltd. - Employee Leave Policy",
    [
        "Employees are entitled to 24 days of paid leave per calendar year.",
        "Employees should submit planned leave requests at least 3 working days in advance.",
        "All planned leave requests must be approved by the employee's reporting manager.",
        "Employees may use sick leave when they are unable to work due to illness.",
        "Casual leave may be used for personal or short-notice requirements.",
        "For emergency or sick leave, employees should inform their manager as soon as possible.",
        "Unused annual leave may be carried forward up to 10 days into the next calendar year.",
        "The HR department maintains official employee leave records."
    ]
)

create_pdf(
    "attendance_policy.pdf",
    "NovaTech Solutions Pvt. Ltd. - Attendance Policy",
    [
        "Standard working hours are 9:00 AM to 6:00 PM, Monday to Friday.",
        "Employees are expected to record attendance through the company's attendance system.",
        "Employees arriving more than 15 minutes late should inform their reporting manager.",
        "Missing attendance records must be regularized within 2 working days.",
        "Employees should maintain accurate attendance records.",
        "Repeated attendance violations may be reviewed by the HR department."
    ]
)

create_pdf(
    "wfh_policy.pdf",
    "NovaTech Solutions Pvt. Ltd. - Work From Home Policy",
    [
        "Eligible employees may work from home up to 2 days per week.",
        "Work from home requires prior approval from the reporting manager.",
        "Employees working remotely must remain available during standard working hours.",
        "Employees must attend scheduled meetings and remain reachable through official communication channels.",
        "Employees must maintain a suitable working environment and reliable internet connection.",
        "Employees are responsible for completing their assigned work while working remotely."
    ]
)

create_pdf(
    "employee_handbook.pdf",
    "NovaTech Solutions Pvt. Ltd. - Employee Handbook",
    [
        "NovaTech Solutions promotes a professional, respectful, and collaborative workplace.",
        "Employees are expected to follow company policies and maintain professional conduct.",
        "Company systems and data must be used only for authorized business purposes.",
        "Employees must protect confidential company information.",
        "The HR department can be contacted for employee policy questions.",
        "Standard office working hours are 9:00 AM to 6:00 PM, Monday to Friday.",
        "Employees should communicate respectfully with colleagues, managers, and business partners."
    ]
)
# Out:
# Created: documents\leave_policy.pdf
# Created: documents\attendance_policy.pdf
# Created: documents\wfh_policy.pdf
# Created: documents\employee_handbook.pdf

# %% [markdown]
# ### PDF Loader
#
# `PyPDFLoader` loads PDF documents into LangChain `Document` objects. Each page becomes a document containing the page text and metadata such as the source filename and page number.

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_files = list(documents_dir.glob("*.pdf"))

documents = []

for pdf_file in pdf_files:
    loader = PyPDFLoader(str(pdf_file))
    documents.extend(loader.load())

print("PDF files:", len(pdf_files))
print("Total pages:", len(documents))

for doc in documents:
    print(
        doc.metadata.get("source"),
        "-> page",
        doc.metadata.get("page")
    )
# Out:
# PDF files: 4
# Total pages: 4
# documents\attendance_policy.pdf -> page 0
# documents\employee_handbook.pdf -> page 0
# documents\leave_policy.pdf -> page 0
# documents\wfh_policy.pdf -> page 0

# %% [markdown]
# ### Text Splitting
#
# Text splitting divides large documents into smaller chunks so that relevant sections can be retrieved efficiently.
#
# We use `RecursiveCharacterTextSplitter` with a chunk size of 800 characters and an overlap of 100 characters.

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=800,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(documents)

print("Original pages:", len(documents))
print("Generated chunks:", len(chunks))
# Out:
# Original pages: 4
# Generated chunks: 4

# %% [markdown]
# ### Embeddings
#
# Embeddings convert text into numerical vectors that represent semantic meaning.
#
# The embedding flow is:
#
# Document Text → Embedding Model → Numerical Vector
#
# We use the lightweight local `all-MiniLM-L6-v2` model, so document embeddings do not require another API key.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

print("Embedding model loaded successfully.")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embedding model loaded successfully.

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

print("Embedding model loaded successfully.")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 3
#       1 from langchain_huggingface import HuggingFaceEmbeddings
#       2
# ----> 3 embeddings = HuggingFaceEmbeddings(
#       4     model_name="sentence-transformers/all-MiniLM-L6-v2"
#       5 )
#       6
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:97, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      94 else:
#      95     model_cls = sentence_transformers.SentenceTransformer
# ---> 97 self._client = model_cls(
#      98     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      99 )
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\util\decorators.py:41, in deprecated_kwargs.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      39         else:
#      40             kwargs.pop(old_name)
# ---> 41 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\sentence_transformer\model.py:188, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend, similarity_fn_name, truncate_dim)
#     183         raise ValueError(
#     184             "Both `token` and `use_auth_token` are specified. Please only specify the `token` argument."
#     185         )
#     186     token = use_auth_token
# --> 188 super().__init__(
#     189     model_name_or_path=model_name_or_path,
#     190     modules=modules,
#     191     device=device,
#     192     cache_folder=cache_folder,
#     193     trust_remote_code=trust_remote_code,
#     194     revision=revision,
#     195     local_files_only=local_files_only,
#     196     token=token,
#     197     model_kwargs=model_kwargs,
#     198     processor_kwargs=processor_kwargs,
#     199     config_kwargs=config_kwargs,
#     200     model_card_data=model_card_data,
#     201     backend=backend,
#     202     prompts=prompts,
#     203     default_prompt_name=default_prompt_name,
#     204 )
#     205 self.model_card_data: SentenceTransformerModelCardData
#     207 # Handle INSTRUCTOR models
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\base\model.py:222, in BaseModel.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, local_files_only, token, model_kwargs, processor_kwargs, config_kwargs, model_card_data, backend)
#     219         model_name_or_path = f"{self.default_huggingface_organization}/{model_name_or_path}"
#     221 if model_name_or_path:
# --> 222     modules, self.module_kwargs = self._load_modules(
#     223         model_name_or_path,
#     224         token=token,
#     225         cache_folder=cache_folder,
#     226         revision=revision,
#     227         trust_remote_code=trust_remote_code,
#     228         local_files_only=local_files_only,
#     229         model_kwargs=model_kwargs,
#     230         processor_kwargs=processor_kwargs,
#     231         config_kwargs=config_kwargs,
#     232     )
#     234 if modules is not None and not isinstance(modules, OrderedDict):
#     235     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\base\model.py:1023, in BaseModel._load_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#    1021 if model_type_being_loaded == self.model_type:
#    1022     logger.info(f"Loading {self.model_type} model from {model_name_or_path}.")
# -> 1023     return self._load_config_modules(model_name_or_path, **load_kwargs)
#    1025 logger.info(f"Converting {model_type_being_loaded} model {model_name_or_path} to {self.model_type}.")
#    1026 return self._load_converted_modules(model_name_or_path, **load_kwargs, model_type=model_type_being_loaded)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\base\model.py:1229, in BaseModel._load_config_modules(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, processor_kwargs, config_kwargs)
#    1224         module = module_class.load(local_path)
#    1226 else:
#    1227     # Newer modules that support the new loading method are loaded with the new style
#    1228     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 1229     module = module_class.load(
#    1230         model_name_or_path,
#    1231         # Loading-specific keyword arguments
#    1232         subfolder=module_config["path"],
#    1233         token=token,
#    1234         cache_folder=cache_folder,
#    1235         revision=revision,
#    1236         local_files_only=local_files_only,
#    1237         # Module-specific keyword arguments
#    1238         trust_remote_code=trust_remote_code,
#    1239         model_kwargs=model_kwargs,
#    1240         processor_kwargs=processor_kwargs,
#    1241         config_kwargs=config_kwargs,
#    1242         backend=self.backend,
#    1243     )
#    1245 modules[module_config["name"]] = module
#    1246 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:2130, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, processor_kwargs, config_kwargs, backend, **kwargs)
#    2116 """Load a Transformer module from a pretrained model directory or Hugging Face model name."""
#    2117 init_kwargs = cls._load_init_kwargs(
#    2118     model_name_or_path=model_name_or_path,
#    2119     subfolder=subfolder,
#    (...)   2128     backend=backend,
#    2129 )
# -> 2130 return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\util\decorators.py:87, in transformer_kwargs_decorator.<locals>.wrapper(*args, **kwargs)
#      84             kwargs.setdefault(dict_name, {})
#      85             kwargs[dict_name].setdefault("cache_dir", cache_dir)
# ---> 87 return func(*args, **kwargs)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\sentence_transformers\base\modules\transformer.py:671, in Transformer.__init__(self, model_name_or_path, transformer_task, model_kwargs, processor_kwargs, config_kwargs, processing_kwargs, backend, modality_config, module_output_name, unpad_inputs, max_seq_length, do_lower_case, tokenizer_name_or_path)
#     669     processor_kwargs["model_max_length"] = max_seq_length
#     670 with suggest_extra_on_exception():
# --> 671     self.processor = AutoProcessor.from_pretrained(
#     672         tokenizer_name_or_path if tokenizer_name_or_path is not None else model_name_or_path,
#     673         **processor_kwargs,
#     674     )
#     676 # Cap the tokenizer model_max_length at the model's max_position_embeddings
#     677 if self.tokenizer is not None:
#     678     # NOTE: xlnet uses a hardcoded config.max_position_embeddings != -1 to denote no max_length
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\transformers\models\auto\processing_auto.py:339, in AutoProcessor.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     337 for klass in (AutoTokenizer, AutoImageProcessor, AutoVideoProcessor, AutoFeatureExtractor):
#     338     try:
# --> 339         return klass.from_pretrained(
#     340             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     341         )
#     342     except Exception:
#     343         continue
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\transformers\models\auto\tokenization_auto.py:905, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     902     if tokenizer_class is None:
#     903         tokenizer_class = TokenizersBackend
# --> 905     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#     906 elif getattr(config, "tokenizer_class", None):
#     907     _class = config.tokenizer_class
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\transformers\tokenization_utils_base.py:1676, in PreTrainedTokenizerBase.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, trust_remote_code, *init_inputs, **kwargs)
#    1674             vocab_files[f"chat_template_{template_name}"] = f"{CHAT_TEMPLATE_DIR}/{template_file.name}"
#    1675 else:
# -> 1676     for template in list_repo_templates(
#    1677         pretrained_model_name_or_path,
#    1678         local_files_only=local_files_only,
#    1679         revision=revision,
#    1680         cache_dir=cache_dir,
#    1681         token=token,
#    1682     ):
#    1683         template = template.removesuffix(".jinja")
#    1684         vocab_files[f"chat_template_{template}"] = f"{CHAT_TEMPLATE_DIR}/{template}.jinja"
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\transformers\utils\hub.py:149, in list_repo_templates(repo_id, local_files_only, revision, cache_dir, token)
#     145 if not local_files_only:
#     146     try:
#     147         return [
#     148             entry.path.removeprefix(f"{CHAT_TEMPLATE_DIR}/")
# --> 149             for entry in hf_api().list_repo_tree(
#     150                 repo_id=repo_id,
#     151                 revision=revision,
#     152                 path_in_repo=CHAT_TEMPLATE_DIR,
#     153                 recursive=False,
#     154                 token=token,
#     155             )
#     156             if entry.path.endswith(".jinja")
#     157         ]
#     158     except (GatedRepoError, RepositoryNotFoundError, RevisionNotFoundError):
#     159         raise  # valid errors => do not catch
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\huggingface_hub\hf_api.py:4093, in HfApi.list_repo_tree(self, repo_id, path_in_repo, recursive, expand, revision, repo_type, token)
#    4089         headers = self._build_hf_headers(token=token)
#    4090
#    4091         encoded_path_in_repo = "/" + quote(path_in_repo, safe="") if path_in_repo else ""
#    4092         tree_url = f"{self.endpoint}/api/{repo_type}s/{repo_id}/tree/{revision}{encoded_path_in_repo}"
# -> 4093         for path_info in paginate(path=tree_url, headers=headers, params={"recursive": recursive, "expand": expand}):
#    4094             yield (RepoFile(**path_info) if path_info["type"] == "file" else RepoFolder(**path_info))
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\huggingface_hub\utils\_pagination.py:36, in paginate(path, params, headers, timeout)
#      28 """Fetch a list of models/datasets/spaces and paginate through results.
#      29
#      30 This is using the same "Link" header format as GitHub.
#    (...)     33 - https://docs.github.com/en/rest/guides/traversing-with-pagination#link-header
#      34 """
#      35 session = get_session()
# ---> 36 r = session.get(path, params=params, headers=headers, timeout=timeout)
#      37 hf_raise_for_status(r)
#      38 yield from r.json()
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:1053, in Client.get(self, url, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1036 def get(
#    1037     self,
#    1038     url: URL | str,
#    (...)   1046     extensions: RequestExtensions | None = None,
#    1047 ) -> Response:
#    1048     """
#    1049     Send a `GET` request.
#    1050
#    1051     **Parameters**: See `httpx.request`.
#    1052     """
# -> 1053     return self.request(
#    1054         "GET",
#    1055         url,
#    1056         params=params,
#    1057         headers=headers,
#    1058         cookies=cookies,
#    1059         auth=auth,
#    1060         follow_redirects=follow_redirects,
#    1061         timeout=timeout,
#    1062         extensions=extensions,
#    1063     )
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# File ~\anaconda3\Lib\ssl.py:1285, in SSLSocket.recv(self, buflen, flags)
#    1281     if flags != 0:
#    1282         raise ValueError(
#    1283             "non-zero flags not allowed in calls to recv() on %s" %
#    1284             self.__class__)
# -> 1285     return self.read(buflen)
#    1286 else:
#    1287     return super().recv(buflen, flags)
#
# File ~\anaconda3\Lib\ssl.py:1140, in SSLSocket.read(self, len, buffer)
#    1138         return self._sslobj.read(len, buffer)
#    1139     else:
# -> 1140         return self._sslobj.read(len)
#    1141 except SSLError as x:
#    1142     if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# ### ChromaDB
#
# ChromaDB stores document embeddings and enables similarity-based retrieval.
#
# The knowledge-base pipeline is:
#
# PDF Documents
# ↓
# PyPDFLoader
# ↓
# Text Splitter
# ↓
# Document Chunks
# ↓
# Embeddings
# ↓
# ChromaDB

# %%
from langchain_chroma import Chroma

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory="chroma_db",
    collection_name="novatech_knowledge_base"
)

print("ChromaDB vector store created successfully.")
# Out:
# ChromaDB vector store created successfully.

# %% [markdown]
# ### Retriever
#
# A retriever finds the most relevant document chunks for a user's question.
#
# We retrieve the top 3 most similar chunks from ChromaDB.

# %%
retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}
)

print("Retriever created successfully.")
# Out:
# Retriever created successfully.

# %% [markdown]
# ### Retrieval-Augmented Generation (RAG)
#
# Retrieval-Augmented Generation (RAG) combines information retrieved from the company knowledge base with the language model.
#
# Instead of asking the LLM to answer from its general knowledge, relevant company document chunks are retrieved first and provided as context to the model.
#
# The RAG flow is:
#
# User Question
# ↓
# Retriever
# ↓
# Relevant Document Chunks
# ↓
# Prompt
# ↓
# OpenRouter LLM
# ↓
# Grounded Answer

# %% [markdown]
# ### RAG Prompt
#
# The model is instructed to answer only using information retrieved from the NovaTech Solutions knowledge base.
#
# If the required information is not present in the retrieved documents, the model should clearly state that the information is not available rather than inventing a company policy.

# %%
from langchain_core.prompts import ChatPromptTemplate

rag_prompt = ChatPromptTemplate.from_template("""
You are an internal AI assistant for NovaTech Solutions Pvt. Ltd.

Answer the employee's question using ONLY the provided company documents.

If the answer cannot be found in the provided documents, clearly say that the information is not available in the company knowledge base.

Do not invent company policies.

Context:
{context}

Employee Question:
{question}
""")

print("RAG prompt created successfully.")
# Out:
# RAG prompt created successfully.

# %%
def format_docs(docs):
    return "\n\n".join(
        doc.page_content for doc in docs
    )

rag_chain = (
    {
        "context": retriever | format_docs,
        "question": lambda x: x
    }
    | rag_prompt
    | llm
)

print("RAG chain created successfully.")
# Out:
# RAG chain created successfully.

# %% [markdown]
# ### RAG Testing
#
# The RAG system was tested using questions related to leave, work-from-home, working hours, and information that is not present in the knowledge base.
#
# The system retrieves relevant company policy chunks and provides them as context to the OpenRouter LLM. For questions outside the available knowledge base, the system is instructed not to invent company policies.

# %%
# Rag test code

def ask_rag(question):
    response = rag_chain.invoke(question)

    retrieved_docs = retriever.invoke(question)

    print("Question:")
    print(question)

    print("\nAnswer:")
    print(response.content)

    print("\nSources:")

    for doc in retrieved_docs:
        print("-", Path(doc.metadata["source"]).name)

# %%
# RAG test cases
ask_rag("What is the annual leave entitlement?")
# Out:
# Question:
# What is the annual leave entitlement?
#
# Answer:
# The annual leave entitlement is **24 days of paid leave per calendar year**.
#
# Sources:
# - leave_policy.pdf
# - leave_policy.pdf
# - wfh_policy.pdf

# %%
ask_rag("How many days can an eligible employee work from home?")
# Out:
# Question:
# How many days can an eligible employee work from home?
#
# Answer:
# Eligible employees may work from home **up to 2 days per week**.
#
# Sources:
# - wfh_policy.pdf
# - wfh_policy.pdf
# - leave_policy.pdf

# %%
ask_rag("What are the standard working hours?")
# Out:
# Question:
# What are the standard working hours?
#
# Answer:
# The standard working hours are **9:00 AM to 6:00 PM, Monday to Friday**.
#
# Sources:
# - attendance_policy.pdf
# - attendance_policy.pdf
# - wfh_policy.pdf

# %%
ask_rag("What is NovaTech's maternity leave policy?")
# Out:
# Question:
# What is NovaTech's maternity leave policy?
#
# Answer:
# I’m sorry, but the NovaTech employee knowledge base does not contain any information about a maternity leave policy.
#
# Sources:
# - leave_policy.pdf
# - leave_policy.pdf
# - employee_handbook.pdf

# %% [markdown]
# ## 10. Multi-Agent System
#
# The Enterprise Operations AI Assistant will eventually contain multiple specialized agents.
#
# Each agent will be responsible for a specific business function.
#
# In this step, the HR Agent is implemented.
#
# ### 10.1 HR Agent
#
# The HR Agent is responsible for answering employee questions related to leave, attendance, work from home, and general employee policies.
#
# It uses the existing company knowledge base and RAG system to provide answers grounded in NovaTech Solutions Pvt. Ltd. documents.

# %%
from langchain_core.prompts import ChatPromptTemplate

hr_prompt = ChatPromptTemplate.from_template("""
You are the HR Assistant for NovaTech Solutions Pvt. Ltd.

Your responsibility is to answer employee questions related to:

- Leave
- Attendance
- Work From Home
- Employee policies
- Employee handbook information

Use the provided company knowledge base as your primary source.

IMPORTANT RULES:

1. Answer using the retrieved company documents.
2. Do not invent company policies.
3. If the information is not available in the retrieved documents, clearly state that the information is not available in the company knowledge base.
4. Keep answers clear, professional, and concise.
5. When appropriate, mention the source document used.

Retrieved Company Information:
{context}

Employee Question:
{question}
""")

print("HR prompt created successfully.")
# Out:
# HR prompt created successfully.

# %%
# HR Agent

def hr_agent(question):
    retrieved_docs = retriever.invoke(question)

    context = "\n\n".join(
        doc.page_content for doc in retrieved_docs
    )

    chain = hr_prompt | llm

    response = chain.invoke({
        "context": context,
        "question": question
    })

    sources = list(dict.fromkeys(
        Path(doc.metadata["source"]).name
        for doc in retrieved_docs
    ))

    return {
        "answer": response.content,
        "sources": sources
    }

print("HR agent function created successfully.")
# Out:
# HR agent function created successfully.

# %%
# Test HR Agent
def test_hr_agent(question):
    result = hr_agent(question)

    print("Question:")
    print(question)

    print("\nAnswer:")
    print(result["answer"])

    print("\nSources:")
    for source in result["sources"]:
        print("-", source)

# %% [markdown]
# ### HR Agent test cases

# %%
# tc 1
test_hr_agent(
    "What is the annual leave entitlement?"
)
# tc 2
test_hr_agent(
    "How many days in advance should I apply for planned leave?"
)
# tc 3
test_hr_agent(
    "How many days can an eligible employee work from home?"
)
# tc 4
test_hr_agent(
    "What are the standard working hours?"
)
# tc 5
test_hr_agent(
    "What are employees expected to do with confidential company information?"
)
# tc 6
test_hr_agent(
    "What is NovaTech's maternity leave policy?"
)
# Out:
# Question:
# What is the annual leave entitlement?
#
# Answer:
# **Annual leave entitlement:**
# Employees are entitled to **24 days of paid leave per calendar year**.
#
# *Source: NovaTech Solutions Pvt. Ltd. – Employee Leave Policy*
#
# Sources:
# - leave_policy.pdf
# - wfh_policy.pdf
# Question:
# How many days in advance should I apply for planned leave?
#
# Answer:
# You should submit a planned leave request at least **3 working days in advance**.
# *Source: NovaTech Solutions Pvt. Ltd. – Employee Leave Policy*
#
# Sources:
# - leave_policy.pdf
# - wfh_policy.pdf
# Question:
# How many days can an eligible employee work from home?
#
# Answer:
# Eligible employees may work from home **up to 2 days per week**.
# *Source: NovaTech Solutions Pvt. Ltd. – Work From Home Policy*
#
# Sources:
# - wfh_policy.pdf
# - leave_policy.pdf
# Question:
# What are the standard working hours?
#
# Answer:
# The standard working hours at NovaTech Solutions Pvt. Ltd. are **9:00 AM to 6:00 PM, Monday to Friday**.
# *Source: NovaTech Solutions Pvt. Ltd. – Attendance Policy*
#
# Sources:
# - attendance_policy.pdf
# - wfh_policy.pdf
# Question:
# What are employees expected to do with confidential company information?
#
# Answer:
# Employees are required to **protect confidential company information**. This means they must keep such information secure, use it only for authorized business purposes, and avoid unauthorized disclosure or sharing.
#
# *Source: NovaTech Solutions Pvt. Ltd. - Employee Handbook*
#
# Sources:
# - employee_handbook.pdf
# - leave_policy.pdf
# Question:
# What is NovaTech's maternity leave policy?
#
# Answer:
# I’m sorry, but the company knowledge base does not contain any information about NovaTech’s maternity leave policy.
#
# Sources:
# - leave_policy.pdf
# - employee_handbook.pdf

# %% [markdown]
# ### HR Agent vs Basic RAG
#
# In the previous RAG implementation, a question was directly passed to the retriever and then to the LLM.
#
# The HR Agent adds a specialized role and instructions around the existing RAG system.
#
# Basic RAG:
#
# Question
# ↓
# Retriever
# ↓
# LLM
# ↓
# Answer
#
# HR Agent:
#
# Employee HR Question
# ↓
# HR Agent
# ↓
# HR-specific instructions
# ↓
# Retriever
# ↓
# Company Documents
# ↓
# LLM
# ↓
# HR Answer
#
# The HR Agent is therefore a specialized component designed specifically for employee and HR-related questions.

# %% [markdown]
# ### 10.2 Research Agent
#
# The Research Agent is responsible for answering questions that require external information.
#
# Unlike the HR Agent, which uses the internal NovaTech Solutions knowledge base, the Research Agent uses Wikipedia to obtain external information.
#
# The Research Agent retrieves relevant Wikipedia content and passes it to the existing OpenRouter LLM to generate a concise research summary.
#
# #### Research Agent Responsibilities
#
# The Research Agent handles:
#
# - General research questions
# - Factual information requests
# - Topics that require external information
# - Wikipedia-based research and summarization
#
# The agent should base its answers on retrieved Wikipedia information and should not invent unsupported facts.
#
# #### Research Agent Responsibilities
#
# The Research Agent handles:
#
# - General research questions
# - Factual information requests
# - Topics that require external information
# - Wikipedia-based research and summarization
#
# The agent should base its answers on retrieved Wikipedia information and should not invent unsupported facts.

# %%
import requests

def wikipedia_search(query):
    url = f"https://en.wikipedia.org/api/rest_v1/page/summary/{query.replace(' ', '_')}"

    headers = {
        "User-Agent": "NovaTech-Research-Agent/1.0 (academic project)"
    }

    response = requests.get(url, headers=headers, timeout=10)
    response.raise_for_status()

    data = response.json()

    return {
        "title": data.get("title", query),
        "content": data.get("extract", ""),
        "url": data.get("content_urls", {})
                    .get("desktop", {})
                    .get("page", "")
    }

# %%
wiki_result = wikipedia_search("Artificial Intelligence")

print("Title:", wiki_result["title"])
print("\nContent:")
print(wiki_result["content"][:3000])
print("\nURL:", wiki_result["url"])
# Out:
# Title: Artificial intelligence
#
# Content:
# Artificial intelligence (AI) is the capability of computational systems to perform tasks typically associated with human intelligence, such as learning, reasoning, problem-solving, perception, and decision-making. It is a field of research in engineering, mathematics, and computer science that develops and studies methods and software that enable machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
#
# URL: https://en.wikipedia.org/wiki/Artificial_intelligence

# %% [markdown]
# #### Research Prompt
#
# The Research Agent uses a dedicated prompt to instruct the LLM to summarize information retrieved from Wikipedia.
#
# The model is instructed to use the retrieved research information, avoid unsupported claims, and clearly present the findings.

# %%
from langchain_core.prompts import ChatPromptTemplate

research_prompt = ChatPromptTemplate.from_template("""
You are the Research Agent for NovaTech Solutions Pvt. Ltd.

Your responsibility is to research topics using reliable external sources.

Analyze the provided research information and produce a clear, factual summary.

Rules:
1. Base the answer only on the provided research information.
2. Do not invent facts that are not supported by the research.
3. Clearly distinguish facts from uncertainty.
4. Keep the final answer concise but useful.
5. Mention the source used when appropriate.

Research Question:
{question}

Research Information:
{research_results}
""")

print("Research prompt created successfully.")
# Out:
# Research prompt created successfully.

# %% [markdown]
# ## Research Agent implementation

# %%
def research_agent(question):
    wiki_result = wikipedia_search(question)

    research_results = f"""
Title: {wiki_result['title']}

Content:
{wiki_result['content']}
"""

    chain = research_prompt | llm

    response = chain.invoke({
        "question": question,
        "research_results": research_results
    })

    return {
        "answer": response.content,
        "sources": [
            {
                "title": wiki_result["title"],
                "url": wiki_result["url"]
            }
        ]
    }

# %% [markdown]
# ## Research Agent test

# %%
result = research_agent("Artificial Intelligence")

print("Research Summary:")
print(result["answer"])

print("\nSources:")
for source in result["sources"]:
    print("-", source["title"])
    print(" ", source["url"])
# Out:
# Research Summary:
# **Summary of the provided research**
#
# Artificial intelligence (AI) is defined as the capability of computational systems to perform tasks that are normally associated with human intelligence. These tasks include learning, reasoning, problem‑solving, perception, and decision‑making. AI research spans engineering, mathematics, and computer science, focusing on developing methods and software that allow machines to perceive their environment and use learning and intelligence to take actions that maximize their chances of achieving defined goals.
#
# *Source: “Artificial intelligence” (research information supplied).*
#
# Sources:
# - Artificial intelligence
#   https://en.wikipedia.org/wiki/Artificial_intelligence

# %% [markdown]
# ## Research Agent test cases
#
# Test 1 — Microsoft
# Test 2 — Generative AI trends
# Test 3 — Wikipedia

# %%
# tc 1
result = research_agent("Research Microsoft's latest AI products.")

print("Research Summary:")
print(result["answer"])

print("\nSources:")
for source in result["sources"]:
    print("-", source["title"])
    print(" ", source["url"])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[56], line 2
#       1 # tc 1
# ----> 2 result = research_agent("Research Microsoft's latest AI products.")
#       3
#       4 print("Research Summary:")
#       5 print(result["answer"])
#
# Cell In[39], line 2, in research_agent(question)
#       1 def research_agent(question):
# ----> 2     wiki_result = wikipedia_search(question)
#       3
#       4     research_results = f"""
#       5 Title: {wiki_result['title']}
#
# Cell In[35], line 11, in wikipedia_search(query)
#       7         "User-Agent": "NovaTech-Research-Agent/1.0 (academic project)"
#       8     }
#       9
#      10     response = requests.get(url, headers=headers, timeout=10)
# ---> 11     response.raise_for_status()
#      12
#      13     data = response.json()
#      14
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\requests\models.py:1167, in Response.raise_for_status(self)
#    1162     http_error_msg = (
#    1163         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1164     )
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://en.wikipedia.org/api/rest_v1/page/summary/Research_Microsoft's_latest_AI_products.

# %%
# tc 2
result = research_agent("What are the latest Generative AI trends?")

print("Research Summary:")
print(result["answer"])

print("\nSources:")
for source in result["sources"]:
    print("-", source["title"])
    print(" ", source["url"])
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 # tc 2
# ----> 2 result = research_agent("What are the latest Generative AI trends?")
#       3
#       4 print("Research Summary:")
#       5 print(result["answer"])
#
# Cell In[39], line 2, in research_agent(question)
#       1 def research_agent(question):
# ----> 2     wiki_result = wikipedia_search(question)
#       3
#       4     research_results = f"""
#       5 Title: {wiki_result['title']}
#
# Cell In[35], line 11, in wikipedia_search(query)
#       7         "User-Agent": "NovaTech-Research-Agent/1.0 (academic project)"
#       8     }
#       9
#      10     response = requests.get(url, headers=headers, timeout=10)
# ---> 11     response.raise_for_status()
#      12
#      13     data = response.json()
#      14
#
# File ~\OneDrive\Desktop\Projects\EEC\enterprise-ops-ai-assistant\.venv\Lib\site-packages\requests\models.py:1167, in Response.raise_for_status(self)
#    1162     http_error_msg = (
#    1163         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1164     )
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://en.wikipedia.org/api/rest_v1/page/summary/What_are_the_latest_Generative_AI_trends

# %%
# tc 3
result = research_agent("Explain the history of artificial intelligence.")

print("Research Summary:")
print(result["answer"])

print("\nSources:")
for source in result["sources"]:
    print("-", source["title"])
    print(" ", source["url"])
